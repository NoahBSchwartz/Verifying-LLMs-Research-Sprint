# %% [markdown]
# 1. Test how well the method does in training and use that to get a confidence interval
# 2. Make a prediction for one input by taking into account how the input performs on our method and the confidence interval we obtained
# 3. Make a prediction for a whole set of inputs by taking into account how the inputs perform on our method and the confidence interval we obtained
